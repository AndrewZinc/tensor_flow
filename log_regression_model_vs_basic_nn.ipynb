# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('./Data/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver='lbfgs',max_iter=200)

# Train the model
log_classifier.fit(X_train, y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f'Logistic Regression model accuracy: {accuracy_score(y_test,y_pred):.3f}')
# Out:
# Logistic Regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation='relu', input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Compile the model and customize metrics
nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7142 - accuracy: 0.5278
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6792 - accuracy: 0.6059
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6488 - accuracy: 0.6441
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6209 - accuracy: 0.7066
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5971 - accuracy: 0.7361
# Epoch 6/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5755 - accuracy: 0.7483
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5574 - accuracy: 0.7569
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5415 - accuracy: 0.7500
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.7517
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5178 - accuracy: 0.7604
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5084 - accuracy: 0.7587
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5008 - accuracy: 0.7587
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4940 - accuracy: 0.7656
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4883 - accuracy: 0.7639
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4834 - accuracy: 0.7726
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4788 - accuracy: 0.7726
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4754 - accuracy: 0.7743
# Epoch 18/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.7778
# Epoch 19/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4687 - accuracy: 0.7812
# Epoch 20/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4665 - accuracy: 0.7830
# Epoch 21/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.7865
# Epoch 22/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4621 - accuracy: 0.7865
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7882
# Epoch 24/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.7899
# Epoch 25/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4566 - accuracy: 0.7882
# Epoch 26/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4553 - accuracy: 0.7865
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4541 - accuracy: 0.7899
# Epoch 28/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4529 - accuracy: 0.7899
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4517 - accuracy: 0.7882
# Epoch 30/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.7917
# Epoch 31/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.8021
# Epoch 32/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4486 - accuracy: 0.8021
# Epoch 33/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.8021
# Epoch 34/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4467 - accuracy: 0.8021
# Epoch 35/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4460 - accuracy: 0.8021
# Epoch 36/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4454 - accuracy: 0.8003
# Epoch 37/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4446 - accuracy: 0.8003
# Epoch 38/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4437 - accuracy: 0.8021
# Epoch 39/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4431 - accuracy: 0.8021
# Epoch 40/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4421 - accuracy: 0.7986
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.7986
# Epoch 42/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4411 - accuracy: 0.7986
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.7986
# Epoch 44/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4398 - accuracy: 0.7951
# Epoch 45/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.7969
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4389 - accuracy: 0.7934
# Epoch 47/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4379 - accuracy: 0.7934
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4380 - accuracy: 0.7934
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4373 - accuracy: 0.7951
# Epoch 50/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4367 - accuracy: 0.7917
# 6/6 - 0s - loss: 0.4778 - accuracy: 0.7292 - 128ms/epoch - 21ms/step
# Loss: 0.47777023911476135, Accuracy: 0.7291666865348816
